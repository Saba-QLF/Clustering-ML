# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_digits
mnist = load_digits()
mnist.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'feature_names', 'target_names', 'images', 'DESCR'])

# %%
X = mnist['data']
X.shape
# Out:
# (1797, 64)

# %%
X = mnist['data']
np.random.shuffle(X)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
# Standardising the values
pca_std = StandardScaler().fit_transform(X)

# Call the PCA method with 2 components. 
pca = PCA(n_components=2)
X_2 = pca.fit(pca_std).transform(pca_std)

# %%
X_2
# Out:
# array([[-4.83175279,  0.74503219],
#        [-0.70021155, -0.76145451],
#        [ 5.55958536,  7.93333084],
#        ...,
#        [ 0.93210005, -4.37156883],
#        [-2.84960411, -0.84303561],
#        [-3.54263397, -0.54845727]])

# %%
plt.scatter(X_2[:, 0], X_2[:, 1],
            c='white',
            marker='o',
            s = 50,
            edgecolors='black')

# %%
from sklearn.cluster import KMeans
km = KMeans(n_clusters=10,
           init='k-means++',
           n_init=10,
           max_iter=300,
           random_state=0)
y_km = km.fit_predict(X_2)

# %%
plt.scatter(X_2[:, 0], X_2[:, 1],
            c=y_km,
            marker='o',
            s = 50,
            edgecolors='black')
plt.scatter(km.cluster_centers_[:, 0],
           km.cluster_centers_[:,1],
           marker='*',
            c='red',
           s=250,
           edgecolors='black')

# %% [markdown]
# nowwww
# the question is, how we know the cluster had choosen right ?

# %% [markdown]
# # oh man, we have a manythings to learn
